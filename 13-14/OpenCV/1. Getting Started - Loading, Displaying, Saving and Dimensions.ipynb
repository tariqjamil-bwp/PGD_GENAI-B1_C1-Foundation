# %% [markdown]
# Topics Covered:
# 1. Import the OpenCV Model in Python
# 2. Load Images
# 3. Display Images
# 4. Save Images
# 5. Getting the Image Dimensions

# %%
# This is how we import OpenCV, we can't use OpenCV's functions without first doing this
#!pip install opencv-python
import cv2
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/tjamil/anaconda3/envs/genai/lib/python3.12/site-packages (from opencv-python) (1.26.3)
# Using cached opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80

# %%
# Let's see what version we're running
print(cv2.__version__)
# Out:
# 4.9.0

# %% [markdown]
# ### **Dowloading Images**
#
# If using Google Colab, we'll have to **upload our image**.
#
# Colab is a Jupyther Notebook environment that runs on the **cloud** using Google's servers. As such, any file we wish to use needs to be uploaded to their servers.

# %%
image_path = 'https://www.bing.com/images/search?view=detailV2&ccid=70LjAid6&id=33DC5B152D215C35B9870DA010B1DBC7A3202144&thid=OIP.70LjAid6ywdt68MBhM22CQAAAA&mediaurl=https%3A%2F%2Fi.pinimg.com%2Foriginals%2F18%2F38%2F75%2F183875363e51fa220d07587038c6870c.jpg&exph=559&expw=417&form=IRPFED&ck=23AC4881E8ADF7708C7DE29DAA4C71DF&reqid=55D3B108C78F4C44BC7EAEF15A43AA2A&selectedindex=17&itb=0&idpp=insfeed&ajaxhist=0&ajaxserp=0&simid=607997778709659170&cdnurl=https%3A%2F%2Fth.bing.com%2Fth%2Fid%2FR.ef42e302277acb076debc30184cdb609%3Frik%3DRCEgo8fbsRCgDQ%26pid%3DImgRaw%26r%3D0&vt=2'

# %% [markdown]
# ### **Loading Images**

# %%
# Load an image using 'imread' specifying the path to image
image = cv2.imread(image_path)
# Out:
# [ WARN:0@227.514] global loadsave.cpp:248 findDecoder imread_('https://www.bing.com/images/search?view=detailV2&ccid=70LjAid6&id=33DC5B152D215C35B9870DA010B1DBC7A3202144&thid=OIP.70LjAid6ywdt68MBhM22CQAAAA&mediaurl=https%3A%2F%2Fi.pinimg.com%2Foriginals%2F18%2F38%2F75%2F183875363e51fa220d07587038c6870c.jpg&exph=559&expw=417&form=IRPFED&ck=23AC4881E8ADF7708C7DE29DAA4C71DF&reqid=55D3B108C78F4C44BC7EAEF15A43AA2A&selectedindex=17&itb=0&idpp=insfeed&ajaxhist=0&ajaxserp=0&simid=607997778709659170&cdnurl=https%3A%2F%2Fth.bing.com%2Fth%2Fid%2FR.ef42e302277acb076debc30184cdb609%3Frik%3DRCEgo8fbsRCgDQ%26pid%3DImgRaw%26r%3D0&vt=2'): can't open/read file: check file path/integrity

# %% [markdown]
# ### **Displaying Images**

# %%
from matplotlib import pyplot as plt

#Show the image with matplotlib
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 4
#       1 from matplotlib import pyplot as plt
#       3 #Show the image with matplotlib
# ----> 4 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#       5 plt.show()
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %% [markdown]
# Let's create a simple function to make displaying our images simpler and easier

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Let's test it out
imshow("Displaying Our First Image", image)

# %% [markdown]
# ### **Saving Images**

# %%
# Simply use 'imwrite' specificing the file name and the image to be saved
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
# Or save it as a PNG (Portable Network Graphics) which is a Lossless bitmap image format
cv2.imwrite('output.png', image)
# Out:
# True

# %% [markdown]
# ### **Displaying Image Dimensions**
#
# Remember Images are arrays:
#
# ![](https://raw.githubusercontent.com/rajeevratan84/ModernComputerVision/main/array.png?token=ADLZD2HNEL33JAKTYRM3B5C7WMIV4)

# %% [markdown]
# We need to use numpy to perform this operation. Don't worry, numpy will become one of your best friends if you're learning a Data Science and Computer Vision.

# %%
# Import numpy
import numpy as np

print(image.shape)
# Out:
# (960, 1280, 3)

# %%
# To access a dimension, simply index it by using 0, 1 or 2.
image.shape[0]
# Out:
# 960

# %% [markdown]
# You can see the first dimension is the height and it's 960 pixels
#
# The second dimension is the width which is 1280 pixels.
#
# We can print them out nicely like this:

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 960 pixels
# Width of Image: 1280 pixels
# Depth of Image: 3 colors components
